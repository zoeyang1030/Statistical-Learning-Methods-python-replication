# %%
import numpy as np
import matplotlib.pyplot as plt

from Tools.sample import *
from Tools.visualization import *
from Models.Perceptron import *

# %%
X, y = gen_class(n=80, interval=1, label_type=1, random_seed=1)
X_train, X_test, y_train, y_test = split_train_test(X, y, 0.3, random_seed=1)
# Out:
# X.shape: (160, 2)

# %%
model = PerceptronLinearAlgorithm(model_type='averaged', max_iter=1e4, m=0.1, lr=1)
model.fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 0.9464285714285714

# %%
model.score(X_test, y_test)
# Out:
# 0.875

# %%
perceptron_viz = LinearClassifierPlot()
perceptron_viz.scatter_plot(X_test, y_test)
perceptron_viz.hyperplane_plot(model, 'Model', 'black', '--')

# %%
perceptron_viz = LinearClassifierPlot()
perceptron_viz.scatter_plot(X_train, y_train)
perceptron_viz.hyperplane_plot(model, 'Model', 'black', '--')
