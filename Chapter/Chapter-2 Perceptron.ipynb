# %%
import numpy as np
import matplotlib.pyplot as plt

from Tools.sample import *
from Tools.visualization import *
from Models.Perceptron import *

# %%
X, y = gen_class(n=40, label_type=1, random_seed=1)
X_train, X_test, y_train, y_test = split_train_test(X, y, 0.3)
m = Perceptron()
m.fit(X_train, y_train)
# Out:
# X.shape: (80, 2)

# %%
perceptron_viz = LinearClassifierPlot()
perceptron_viz.scatter_plot(X_train, y_train)
perceptron_viz.hyperplane_plot(m, 'ss', 'black', '--')
